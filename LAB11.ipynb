# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasoontiwari7/algorithm-lab/blob/main/LAB11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %%
import sys

def tsp(graph):
    n = len(graph)
    memo = {}

    def visit(city, mask):
        if mask == (1 << n) - 1:
            return graph[city][0], [0]

        state = (city, mask)
        if state in memo:
            return memo[state]

        best_cost = float('inf')
        best_path = []

        for next_city in range(n):
            if (mask & (1 << next_city)) == 0:
                cost, path = visit(next_city, mask | (1 << next_city))
                new_cost = graph[city][next_city] + cost

                if new_cost < best_cost:
                    best_cost = new_cost
                    best_path = [next_city] + path

        memo[state] = (best_cost, best_path)
        return best_cost, best_path

    min_cost, path = visit(0, 1)
    full_path = [0] + path
    return min_cost, full_path

def get_user_graph():
    try:
        n = int(input("Enter number of cities: "))
        print("Enter adjacency matrix row by row (space-separated):")
        graph = []
        for i in range(n):
            row = list(map(int, input().split()))
            graph.append(row)
        return graph
    except ValueError:
        print("Invalid input")
        sys.exit()

if __name__ == "__main__":
    choice = input("Use default graph? (y/n): ")
    if choice.lower() == 'y':
        graph = [
            [0, 10, 15, 20],
            [10, 0, 35, 25],
            [15, 35, 0, 30],
            [20, 25, 30, 0]
        ]
    else:
        graph = get_user_graph()

    cost, path = tsp(graph)
    print("Minimum travelling cost:", cost)
    print("Path taken:", " -> ".join(map(str, path)))
